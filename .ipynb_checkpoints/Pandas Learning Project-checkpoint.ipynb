# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\tenyj\Downloads\stack-overflow-developer-survey-2023/survey_results_public.csv",index_col='ResponseId')
df_schema=pd.read_csv(r"C:\Users\tenyj\Downloads\stack-overflow-developer-survey-2023/survey_results_schema.csv",index_col='qid')

# %%
df
#df_schema
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.info()
df_schema.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
#Accessing the ccolumns

df[['Age','Country']]
# Out:
#                            Age                       Country
# ResponseId
# 1              18-24 years old                           NaN
# 2              25-34 years old      United States of America
# 3              45-54 years old      United States of America
# 4              25-34 years old      United States of America
# 5              25-34 years old                   Philippines
# ...                        ...                           ...
# 89180          25-34 years old                        Brazil
# 89181          18-24 years old                       Romania
# 89182        Prefer not to say                        Israel
# 89183       Under 18 years old                   Switzerland
# 89184          35-44 years old  Iran, Islamic Republic of...
#
# [89184 rows x 2 columns]

# %%
#Accessing the rows with iloc

#df.iloc[0]
df.iloc[[0,1,2],[1,2]]
# Out:
#                                 MainBranch              Age
# ResponseId
# 1                            None of these  18-24 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  45-54 years old

# %%
#Accessing the rows with loc

#df.loc[[1,2],['MainBranch','Age']]
df.loc[1:3]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# ResponseId
# ...

# %%
df['Employment']
# Out:
# ResponseId
# 1                                                      NaN
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4                                      Employed, full-time
# 5        Employed, full-time;Independent contractor, fr...
#                                ...
# 89180    Employed, full-time;Independent contractor, fr...
# 89181               Student, full-time;Employed, part-time
# 89182                                  I prefer not to say
# 89183               Employed, part-time;Student, part-time
# 89184                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
#we can use slicing to select a range instead of giving them in braces

df.loc[1:3,'Employment':'Country']
# Out:
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
#
#                                                  EdLevel  \
# ResponseId
# 1                                                    NaN
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# ...

# %%
#df.index
df_schema.index
# Out:
# Index(['QID16', 'QID12', 'QID310', 'QID312', 'QID1', 'QID2', 'QID127',
#        'QID296', 'QID308', 'QID297', 'QID190', 'QID25', 'QID276', 'QID281',
#        'QID306', 'QID32', 'QID34', 'QID31', 'QID29', 'QID278', 'QID322',
#        'QID279', 'QID6', 'QID50', 'QID51', 'QID61', 'QID233', 'QID262',
#        'QID263', 'QID264', 'QID265', 'QID275', 'QID274', 'QID71', 'QID282',
#        'QID307', 'QID327', 'QID328', 'QID91', 'QID266', 'QID100', 'QID101',
#        'QID102', 'QID106', 'QID313', 'QID325', 'QID314', 'QID315', 'QID324',
#        'QID316', 'QID319', 'QID320', 'QID321', 'QID295', 'QID299', 'QID287',
#        'QID288', 'QID289', 'QID290', 'QID291', 'QID292', 'QID304', 'QID326',
#        'QID286', 'QID131', 'QID132', 'QID133', 'QID289', 'QID289', 'QID289',
#        'QID289', 'QID289', 'QID289', 'QID289', 'QID289', 'QID290', 'QID290',
#        'QID290'],
#       dtype='object', name='qid')

# %%
df_schema.loc['QID279','question']
# Out:
# 'When buying a new tool or software, how do you discover and research available solutions? Select all that apply.'

# %%
#we can also sort the indexes
# Inplace statement make sure that the changes are permanent

df_schema.sort_index(inplace=True)

# %%
df_schema
#df
# Out:
#               qname                                           question  \
# qid
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID106       SOComm  Do you consider yourself a member of the Stack...
# ...             ...                                                ...
# QID51     CompTotal  What is your current total <b>annual</b> compe...
# QID6        Country  Where do you live? <span style="font-weight: b...
# QID61            S3  <span style="font-size:22px; font-family: aria...
# QID71         OpSys  What is the primary <b>operating system</b> in...
# QID91            S4  <span style="font-size:22px; font-family: aria...
#
#        force_resp    type selector
# qid
# QID1        False      DB       TB
# ...

# %%
##   To filter the data 

high_salary=(df['ConvertedCompYearly']>50000)     #this filter will return a series of boolean values
df.loc[high_salary,['Country','TechList','ConvertedCompYearly']]
# Out:
#                                                       Country      TechList  \
# ResponseId
# 2                                    United States of America   Investigate
# 3                                    United States of America  Given a list
# 4                                    United States of America   Investigate
# 6           United Kingdom of Great Britain and Northern I...           NaN
# 7                                    United States of America           NaN
# ...                                                       ...           ...
# 89158                                                  Canada   Investigate
# 89159                                                  Sweden   Investigate
# 89163                                                  Brazil   Investigate
# 89171                                                  France           NaN
# 89172                                                  Greece           NaN
#
#             ConvertedCompYearly
# ...

# %%
# sorting values based on columns

df_sorted=df.sort_values(by='Country')
df_sorted['Country']
# Out:
# ResponseId
# 21498    Afghanistan
# 65293    Afghanistan
# 1335     Afghanistan
# 33928    Afghanistan
# 77723    Afghanistan
#             ...
# 88821            NaN
# 88829            NaN
# 88831            NaN
# 89029            NaN
# 89160            NaN
# Name: Country, Length: 89184, dtype: object

# %%
# filtering based on a list
df_sorted
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 21498       I agree  I am a developer by profession     35-44 years old
# 65293       I agree  I am a developer by profession     35-44 years old
# 1335        I agree  I am a developer by profession     18-24 years old
# 33928       I agree  I am a developer by profession     18-24 years old
# 77723       I agree     I code primarily as a hobby  Under 18 years old
# ...             ...                             ...                 ...
# 88821       I agree                   None of these     35-44 years old
# 88829       I agree                   None of these     25-34 years old
# 88831       I agree                   None of these     18-24 years old
# 89029       I agree                   None of these     45-54 years old
# 89160       I agree                   None of these   Prefer not to say
#
#                                                    Employment  \
# ResponseId
# ...

# %%
#Filtering can be done on a list as well

countries = ['India', 'France', 'Germany']
filt_list = df['Country'].isin(countries)
df.loc[filt_list, 'Country']
# Out:
# ResponseId
# 10         India
# 16       Germany
# 18        France
# 20       Germany
# 22       Germany
#           ...
# 89165      India
# 89166      India
# 89168      India
# 89169     France
# 89171     France
# Name: Country, Length: 15886, dtype: object

# %%
#filtering based on a substring

# df['LanguageHaveWorkedWith'].unique()
filt_string=df['LanguageHaveWorkedWith'].str.contains('Python',na=False)
df.loc[filt_string,'LanguageHaveWorkedWith']

# df[filt_string]['Country']       to get a certain column from filtered list without using loc
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
#Changing the name of a column

df.rename(columns={'ConvertedCompYearly':'Salary'},inplace=True)
df['Salary']
# Out:
# ResponseId
# 1             NaN
# 2        285000.0
# 3        250000.0
# 4        156000.0
# 5         23456.0
#            ...
# 89180         NaN
# 89181         NaN
# 89182         NaN
# 89183         NaN
# 89184         NaN
# Name: Salary, Length: 89184, dtype: float64

# %%
#changing values in rows

# This shows how apply work on series objects

df['Salary']=df['Salary'].apply(lambda x: x+100)
df['Salary']
# Out:
# ResponseId
# 1             NaN
# 2        285100.0
# 3        250100.0
# 4        156100.0
# 5         23556.0
#            ...
# 89180         NaN
# 89181         NaN
# 89182         NaN
# 89183         NaN
# 89184         NaN
# Name: Salary, Length: 89184, dtype: float64

# %%
# This shows how applymap work on dataframe

###### this will give a error as also have float values in dataset
df.applymap(len)

# applymap is used to work with datframes while apply cab be used for series objects and dataframes

# Map works only on series,it is used to replace values but if some value is not changed it would br assigned as NaN so our data will be lossed
# In such cases we use Replace
# Out:
# C:\Users\tenyj\AppData\Local\Temp\ipykernel_18256\3448084375.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 # This shows how applymap work on dataframe
#       2 ###### this will give a error as also have float values in dataset
# ----> 4 df.applymap(len)
#       6 # applymap is used to work with datframes while apply cab be used for series objects and dataframes
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10174, in DataFrame.applymap(self, func, na_action, **kwargs)
#   10125 """
#   10126 Apply a function to a Dataframe elementwise.
#   10127
#    (...)
#   10167 1  5  5
#   10168 """
#   10169 warnings.warn(
# ...

# %%
# This show how to work with replace in series

df['LearnCodeCoursesCert'].replace({'NaN':'Books'})
# Out:
# ResponseId
# 1                                    NaN
# 2                                  Other
# 3                                    NaN
# 4                                    NaN
# 5                   Other;Codecademy;edX
#                       ...
# 89180                              Udemy
# 89181                                NaN
# 89182                Codecademy;Coursera
# 89183                              Udemy
# 89184    Codecademy;Pluralsight;Coursera
# Name: LearnCodeCoursesCert, Length: 89184, dtype: object

# %%
df_new=df

# %%
#df_new

df_new.sort_values(by=['Country','Salary'],ascending=[True,False],inplace=True)    ###This allows sorting one series object ascending while other in decending
df_new[['Country','Salary']].head(50)
#df_new.loc[23215,'Country']

#df_new['Salary'].nlargest(10)    GIves the largest values from the entire series 
#df.nlargest(10,'Salary')         Gives the largest values from the Dataframe including all the other details

# we can also use nsmallest
# Out:
#                 Country     Salary
# ResponseId
# 88348       Afghanistan  9203783.0
# 86039       Afghanistan    68100.0
# 1335        Afghanistan     2503.0
# 57362       Afghanistan     2388.0
# 17873       Afghanistan     1244.0
# 36049       Afghanistan     1015.0
# 53322       Afghanistan      894.0
# 41679       Afghanistan      748.0
# 39427       Afghanistan      148.0
# 37956       Afghanistan      141.0
# 2642        Afghanistan      133.0
# 2301        Afghanistan        NaN
# 3911        Afghanistan        NaN
# 4222        Afghanistan        NaN
# 4410        Afghanistan        NaN
# 10143       Afghanistan        NaN
# 10377       Afghanistan        NaN
# 14420       Afghanistan        NaN
# 15959       Afghanistan        NaN
# 20378       Afghanistan        NaN
# 21498       Afghanistan        NaN
# 21673       Afghanistan        NaN
# 23095       Afghanistan        NaN
# 26532       Afghanistan        NaN
# 27885       Afghanistan        NaN
# ...

# %%
##  Grouping data

# Median ---  median is not influenced by extremely large or small values

df_new['Salary'].median()

#df_new.median()   ---return median values of all numerical series in the dataframe
# Out:
# 75063.0

# %%
# Describe  --- gives a broad overview on numerical stats

df_new.describe()

# df_new['Salary'].count()
# ---------- Count values in result repersent the number of non-NAN values in the dataset

# df_new['Salary'].value_counts()  
# ---------- give the count of values
# Out:
#           CompTotal       WorkExp        Salary
# count  4.822500e+04  43579.000000  4.801900e+04
# mean   1.036807e+42     11.405126  1.032101e+05
# std    2.276847e+44      9.051989  6.814188e+05
# min    0.000000e+00      0.000000  1.010000e+02
# 25%    6.300000e+04      5.000000  4.400700e+04
# 50%    1.150000e+05      9.000000  7.506300e+04
# 75%    2.300000e+05     16.000000  1.217410e+05
# max    5.000000e+46     50.000000  7.435153e+07

# %%
df_new['Country']
#df_schema.loc['Country']
# Out:
# ResponseId
# 88348    Afghanistan
# 86039    Afghanistan
# 1335     Afghanistan
# 57362    Afghanistan
# 17873    Afghanistan
#             ...
# 88821            NaN
# 88829            NaN
# 88831            NaN
# 89029            NaN
# 89160            NaN
# Name: Country, Length: 89184, dtype: object
